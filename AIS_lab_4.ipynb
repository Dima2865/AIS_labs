# %% [markdown]
# <a href="https://colab.research.google.com/github/Dima2865/AIS_labs/blob/main/AIS_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from google.colab import files
uploader = files.upload()
# Out:
#      <input type="file" id="files-486557d2-6799-4c3f-8291-1bd8910c394f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-486557d2-6799-4c3f-8291-1bd8910c394f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("abalone.csv")
df.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.nunique()
# Out:
# Sex                  3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
col_name = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings']
df.set_axis(col_name, axis = 'columns')
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.dropna(subset = ['Diameter'], inplace=True)
df.Diameter.unique()
df.Diameter = df.Diameter.replace('None', np.nan)

# %%
df[df['Diameter'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
df[df.duplicated() == True]
df.duplicated().sum()
# Out:
# 0

# %%
#------------------------------------------------------------------------------

# %%
# датасет (индекс массы тела) https://www.kaggle.com/datasets/yasserh/bmidataset

uploader = files.upload()
# Out:
#      <input type="file" id="files-d890ae9e-2967-4c10-a100-ecdcf58a7d2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d890ae9e-2967-4c10-a100-ecdcf58a7d2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# загрузка датасета и вывод первых 10 его строк
df1 = pd.read_csv("bmi.csv")
df1.head(10)
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3
# 5    Male     189     104      3
# 6    Male     147      92      5
# 7    Male     154     111      5
# 8    Male     174      90      3
# 9  Female     169     103      4

# %%
# информация о датасете
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
# количество уникальных значений
df1.nunique()
# Out:
# Gender      2
# Height     60
# Weight    110
# Index       6
# dtype: int64

# %%
# проверка на пропущенные значения
df1[df1['Gender'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
df1[df1['Height'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
df1[df1['Weight'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
df1[df1['Index'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
# пропущенных значений нет

# %%
# проверка на наличие дубликатов
df1[df1.duplicated() == True]
# Out:
#      Gender  Height  Weight  Index
# 187  Female     182      84      3
# 310    Male     171     147      5
# 327  Female     167      85      4
# 355    Male     174      90      3
# 365    Male     141      80      5
# 381    Male     191      62      1
# 382    Male     177     117      4
# 395  Female     164      71      3
# 400  Female     195     104      3
# 462    Male     179      56      1
# 482  Female     142      86      5

# %%
# количество дубликатов
df1.duplicated().sum()
# Out:
# 11

# %%
# удаление дубликатов с изменением индексации
df1 = df1.drop_duplicates().reset_index(drop=True)

# %%
# проверка на наличие дубликатов
df1[df1.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
# количество дубликатов
df1.duplicated().sum()
# Out:
# 0
